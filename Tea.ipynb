# %%
import pandas as pd
import numpy as np
import calendar
import itertools


from statsmodels.tsa.stattools import adfuller
from sklearn.model_selection import train_test_split
from statsmodels.tsa.stattools import acf, pacf

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.tsa.api as smt
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA

import warnings
warnings.filterwarnings('ignore')

# %%
como = pd.read_csv('Project - 3 - India_Key_Commodities_Retail_Prices_1997_2015.csv')
como.head()
# Out:
#          Date     Centre      Commodity  Price per Kg Region Country
# 0  25-11-1997    LUCKNOW  Tur/Arhar Dal          15.0  NORTH   INDIA
# 1  25-11-1997     BHOPAL  Tur/Arhar Dal          18.0   WEST   INDIA
# 2  25-11-1997     JAIPUR  Tur/Arhar Dal          20.0   WEST   INDIA
# 3  25-11-1997     SHIMLA  Tur/Arhar Dal          21.5  NORTH   INDIA
# 4  25-11-1997  AHMEDABAD  Tur/Arhar Dal          21.5   WEST   INDIA

# %%
como.shape
# Out:
# (846672, 6)

# %%
date = [pd.datetime.strptime(d,'%d-%m-%Y') for d in como.Date]
como['Timeindex'] = date
como.head()
# Out:
#          Date     Centre      Commodity  Price per Kg Region Country  \
# 0  25-11-1997    LUCKNOW  Tur/Arhar Dal          15.0  NORTH   INDIA
# 1  25-11-1997     BHOPAL  Tur/Arhar Dal          18.0   WEST   INDIA
# 2  25-11-1997     JAIPUR  Tur/Arhar Dal          20.0   WEST   INDIA
# 3  25-11-1997     SHIMLA  Tur/Arhar Dal          21.5  NORTH   INDIA
# 4  25-11-1997  AHMEDABAD  Tur/Arhar Dal          21.5   WEST   INDIA
#
#    Timeindex
# 0 1997-11-25
# 1 1997-11-25
# 2 1997-11-25
# 3 1997-11-25
# 4 1997-11-25

# %%
como['Month-year'] = como.Timeindex.dt.to_period('M')
como.head()
# Out:
#          Date     Centre      Commodity  Price per Kg Region Country  \
# 0  25-11-1997    LUCKNOW  Tur/Arhar Dal          15.0  NORTH   INDIA
# 1  25-11-1997     BHOPAL  Tur/Arhar Dal          18.0   WEST   INDIA
# 2  25-11-1997     JAIPUR  Tur/Arhar Dal          20.0   WEST   INDIA
# 3  25-11-1997     SHIMLA  Tur/Arhar Dal          21.5  NORTH   INDIA
# 4  25-11-1997  AHMEDABAD  Tur/Arhar Dal          21.5   WEST   INDIA
#
#    Timeindex Month-year
# 0 1997-11-25    1997-11
# 1 1997-11-25    1997-11
# 2 1997-11-25    1997-11
# 3 1997-11-25    1997-11
# 4 1997-11-25    1997-11

# %%
north = como[(como.Region == 'NORTH')]

# %%
north.head()
# Out:
#           Date   Centre      Commodity  Price per Kg Region Country  \
# 0   25-11-1997  LUCKNOW  Tur/Arhar Dal          15.0  NORTH   INDIA
# 3   25-11-1997   SHIMLA  Tur/Arhar Dal          21.5  NORTH   INDIA
# 5   25-11-1997    DELHI  Tur/Arhar Dal          22.0  NORTH   INDIA
# 16  26-11-1997    DELHI  Tur/Arhar Dal          22.0  NORTH   INDIA
# 17  26-11-1997   SHIMLA  Tur/Arhar Dal          21.5  NORTH   INDIA
#
#     Timeindex Month-year
# 0  1997-11-25    1997-11
# 3  1997-11-25    1997-11
# 5  1997-11-25    1997-11
# 16 1997-11-26    1997-11
# 17 1997-11-26    1997-11

# %%
north.groupby('Month-year').sum().plot()
plt.show()

# %%
north.groupby('Month-year').mean().plot()
plt.show()

# %%
commodity = north.Commodity.unique()
commodity
# Out:
# array(['Tur/Arhar Dal', 'Tomato', 'Tea Loose', 'Sunflower Oil (Packed)',
#        'Sugar', 'Salt Pack (Iodised)', 'Onion', 'Milk', 'Rice'],
#       dtype=object)

# %%
for i in commodity:
    print(i)
    north[north.Commodity == i].groupby('Month-year').mean().plot()
    plt.show()
# Out:
# Tur/Arhar Dal
# Tomato
# Tea Loose
# Sunflower Oil (Packed)
# Sugar
# Salt Pack (Iodised)
# Onion
# Milk
# Rice

# %% [markdown]
# # Tur/Arhar Dal Analysis in North region

# %% [markdown]
# ## Feature Engineering

# %%
dal = north[north.Commodity == 'Tea Loose']

# %%
dal= dal.groupby('Month-year').mean().reset_index()

# %%
dal.head(10)
# Out:
#   Month-year  Price per Kg
# 0    1997-01    104.666667
# 1    1997-02    104.666667
# 2    1997-03    104.666667
# 3    1997-04    104.666667
# 4    1997-05     96.000000
# 5    1997-08     96.000000
# 6    1997-09     96.000000
# 7    1997-10    104.666667
# 8    1997-11    104.666667
# 9    1997-12    104.923077

# %%
month=dal['Month-year'].dt.month
dal['Month'] = [calendar.month_abbr[i] for i in month]
dal['Year']=dal['Month-year'].dt.year

# %%
dal.head(5)
# Out:
#   Month-year  Price per Kg Month  Year
# 0    1997-01    104.666667   Jan  1997
# 1    1997-02    104.666667   Feb  1997
# 2    1997-03    104.666667   Mar  1997
# 3    1997-04    104.666667   Apr  1997
# 4    1997-05     96.000000   May  1997

# %%
dal.tail()
# Out:
#     Month-year  Price per Kg Month  Year
# 221    2015-08    203.500000   Aug  2015
# 222    2015-09    204.484375   Sep  2015
# 223    2015-10    204.811321   Oct  2015
# 224    2015-11    206.181818   Nov  2015
# 225    2015-12    205.285714   Dec  2015

# %%
len(dal)
# Out:
# 226

# %% [markdown]
# ## Missing Value Treatment

# %%
dal=dal.set_index('Month-year')
dal.head()
# Out:
#             Price per Kg Month  Year
# Month-year
# 1997-01       104.666667   Jan  1997
# 1997-02       104.666667   Feb  1997
# 1997-03       104.666667   Mar  1997
# 1997-04       104.666667   Apr  1997
# 1997-05        96.000000   May  1997

# %%
dal=dal.reindex(pd.period_range(dal.index[0],dal.index[-1], freq='M'))
dal=dal.reset_index()
dal.head(12)
# Out:
#      index  Price per Kg Month    Year
# 0  1997-01    104.666667   Jan  1997.0
# 1  1997-02    104.666667   Feb  1997.0
# 2  1997-03    104.666667   Mar  1997.0
# 3  1997-04    104.666667   Apr  1997.0
# 4  1997-05     96.000000   May  1997.0
# 5  1997-06           NaN   NaN     NaN
# 6  1997-07           NaN   NaN     NaN
# 7  1997-08     96.000000   Aug  1997.0
# 8  1997-09     96.000000   Sep  1997.0
# 9  1997-10    104.666667   Oct  1997.0
# 10 1997-11    104.666667   Nov  1997.0
# 11 1997-12    104.923077   Dec  1997.0

# %%
len(dal)
# Out:
# 228

# %%
#date = pd.date_range(start='31-01-1997', end='31-12-2015',freq='M')

# %%
#newdal = pd.DataFrame({'Timeindex': date})

# %%
#newdal['Month-year'] = newdal.Timeindex.dt.to_period('M')
#newdal.head()

# %%
#dal = newdal.set_index('Month-year').join(dal.set_index('Month-year'))

# %%
#dal.reset_index(inplace=True)

# %%
dal.columns
# Out:
# Index(['index', 'Price per Kg', 'Month', 'Year'], dtype='object')

# %%
dal.columns = ['Month-year', 'Price per Kg', 'Month', 'Year']
dal.head(10)
# Out:
#   Month-year  Price per Kg Month    Year
# 0    1997-01    104.666667   Jan  1997.0
# 1    1997-02    104.666667   Feb  1997.0
# 2    1997-03    104.666667   Mar  1997.0
# 3    1997-04    104.666667   Apr  1997.0
# 4    1997-05     96.000000   May  1997.0
# 5    1997-06           NaN   NaN     NaN
# 6    1997-07           NaN   NaN     NaN
# 7    1997-08     96.000000   Aug  1997.0
# 8    1997-09     96.000000   Sep  1997.0
# 9    1997-10    104.666667   Oct  1997.0

# %%
month=dal['Month-year'].dt.month
dal['Month'] = [calendar.month_abbr[i] for i in month]
dal['Year']=dal['Month-year'].dt.year

# %%
dal.head(12)
# Out:
#    Month-year  Price per Kg Month  Year
# 0     1997-01    104.666667   Jan  1997
# 1     1997-02    104.666667   Feb  1997
# 2     1997-03    104.666667   Mar  1997
# 3     1997-04    104.666667   Apr  1997
# 4     1997-05     96.000000   May  1997
# 5     1997-06           NaN   Jun  1997
# 6     1997-07           NaN   Jul  1997
# 7     1997-08     96.000000   Aug  1997
# 8     1997-09     96.000000   Sep  1997
# 9     1997-10    104.666667   Oct  1997
# 10    1997-11    104.666667   Nov  1997
# 11    1997-12    104.923077   Dec  1997

# %%
dal.isnull().sum()
# Out:
# Month-year      0
# Price per Kg    2
# Month           0
# Year            0
# dtype: int64

# %%
np.mean(dal['Price per Kg'])
# Out:
# 154.68435136357488

# %%
dal.head(12)
# Out:
#    Month-year  Price per Kg Month  Year
# 0     1997-01    104.666667   Jan  1997
# 1     1997-02    104.666667   Feb  1997
# 2     1997-03    104.666667   Mar  1997
# 3     1997-04    104.666667   Apr  1997
# 4     1997-05     96.000000   May  1997
# 5     1997-06           NaN   Jun  1997
# 6     1997-07           NaN   Jul  1997
# 7     1997-08     96.000000   Aug  1997
# 8     1997-09     96.000000   Sep  1997
# 9     1997-10    104.666667   Oct  1997
# 10    1997-11    104.666667   Nov  1997
# 11    1997-12    104.923077   Dec  1997

# %%
dal.tail()
# Out:
#     Month-year  Price per Kg Month  Year
# 223    2015-08    203.500000   Aug  2015
# 224    2015-09    204.484375   Sep  2015
# 225    2015-10    204.811321   Oct  2015
# 226    2015-11    206.181818   Nov  2015
# 227    2015-12    205.285714   Dec  2015

# %%
date = pd.date_range(start='01-31-1997', end='12-31-2015', freq='M')
dal['Timeindex'] = date

# %%
plt.figure(figsize=(15,8))
plt.plot(dal.Timeindex, dal['Price per Kg'], label='Tur/Arhar Dal')
plt.xlabel('Timeindex')
plt.ylabel('Price per Kg')
#plt.title('Onion Price')
plt.legend()
plt.show()

# %%
dal['Price per Kg'].interpolate(method='linear', inplace=True)

# %%
plt.figure(figsize=(15,8))
plt.plot(dal.Timeindex, dal['Price per Kg'],label='Tur/Arhar Dal')
plt.xlabel('Timeindex')
plt.ylabel('Price per Kg')
#plt.title('Onion Price')
plt.legend()
plt.show()

# %%
monthabb = [calendar.month_abbr[i] for i in range(1,13)]
pivottable=pd.pivot_table(dal,values='Price per Kg',columns='Month',index='Year')
pivottable=pivottable.reindex_axis(monthabb,axis=1)
pivottable.plot(figsize=(16,8))
plt.show()

# %%
pivottable.boxplot(figsize=(16,8))
plt.show()

# %% [markdown]
# ## Test-Train Split

# %%
train = dal.head(len(dal)-24)
test = dal.tail(24)

# %%
plt.figure(figsize=(15,8))
plt.plot(train.Timeindex, train['Price per Kg'], label = 'Train')
plt.plot(test.Timeindex, test['Price per Kg'], label= 'Test')
plt.savefig('train-test')
plt.legend()
plt.show()

# %% [markdown]
# ## Define Evaluation Function

# %%
def mape(x,y):
    x,y = np.array(x), np.array(y)
    temp = np.mean(np.abs(x-y)/x)
    return round(temp*100,2)

# %% [markdown]
# ## 1. Simple Exponential Model

# %%
model = SimpleExpSmoothing(np.asarray(train['Price per Kg']))

# %%
s=0
alpha=[]
for i in range(20):
    alpha.append(s)
    s= s+0.05

# %%
alpha_val =[]
mapeval =[]
for i in alpha:
    model_fit = model.fit(smoothing_level=i,optimized=False)
    fcst = model_fit.forecast(len(test['Price per Kg']))
    alpha_val.append(i)
    mapeval.append(mape(test['Price per Kg'], fcst))

# %%
a=pd.DataFrame({'alpha': alpha_val, 'MAPE': mapeval})
a=a.sort_values('MAPE').reset_index()
a.drop('index',axis=1, inplace=True)
a.iloc[0]
# Out:
# alpha    0.1
# MAPE     2.4
# Name: 0, dtype: float64

# %%
model_fit = model.fit(smoothing_level=0.1,optimized=False)
fcst = model_fit.forecast(len(test['Price per Kg']))
test['ForecastSE'] = fcst

# %%
plt.figure(figsize=(15,8))
plt.plot(train.Timeindex, train['Price per Kg'], label = 'Train')
plt.plot(test.Timeindex, test['Price per Kg'], label= 'Test')
plt.plot(test.Timeindex, test['ForecastSE'], label= 'Forecast')
plt.legend()
plt.show()

# %%
print('The MAPE value for Simple Exponential is : ', mape(test['Price per Kg'],test['ForecastSE']))
# Out:
# The MAPE value for Simple Exponential is :  2.4

# %% [markdown]
# ## 2. Double Exponential Model or Holt Linear Model

# %%
model = Holt(np.asarray(train['Price per Kg']))

# %%
s=0
alpha=[]
beta=[]
for i in range(20):
    alpha.append(s)
    beta.append(s)
    s= s+0.05

# %%
alpha_val = []
beta_val = []
mapeval = []
for i in alpha:
    for j in beta:
        model_fit = model.fit(smoothing_level=i, smoothing_slope=j, optimized=False)
        fcst = model_fit.forecast(len(test['Price per Kg']))
        alpha_val.append(i)
        beta_val.append(j)
        mapeval.append(mape(test['Price per Kg'], fcst))

# %%
a=pd.DataFrame({'alpha': alpha_val, 'beta': beta_val,'MAPE': mapeval})
a=a.sort_values('MAPE').reset_index()
a.drop('index',axis=1, inplace=True)
a.iloc[0]
# Out:
# alpha    0.15
# beta     0.75
# MAPE     1.12
# Name: 0, dtype: float64

# %%
model_fit = model.fit(smoothing_level=0.15, smoothing_slope=0.75, optimized=False)
fcst = model_fit.forecast(len(test['Price per Kg']))
test['ForecastDE'] = fcst

# %%
model = Holt(np.asarray(dal['Price per Kg']))
model_fit = model.fit(smoothing_level=0.15, smoothing_slope=0.75, optimized=False)
fcst = model_fit.forecast(12)
daldf = pd.DataFrame(fcst)
daldf.to_csv('teaforecast.csv')

# %%
plt.figure(figsize=(15,8))
plt.plot(train.Timeindex, train['Price per Kg'], label = 'Train')
plt.plot(test.Timeindex, test['Price per Kg'], label= 'Test')
plt.plot(test.Timeindex, test['ForecastDE'], label= 'Forecast')
plt.legend()
plt.show()

# %%
print('The MAPE value for Double Exponential is : ', mape(test['Price per Kg'],test['ForecastDE']))
# Out:
# The MAPE value for Double Exponential is :  1.12

# %% [markdown]
# ## 3. Holt-Winter Model

# %%
model = ExponentialSmoothing(np.asarray(train['Price per Kg']),seasonal_periods=12,seasonal='add')

# %%
s=0
alpha=[]
beta=[]
gamma=[]
for i in range(20):
    alpha.append(s)
    beta.append(s)
    gamma.append(s)
    s= s+0.05

# %%
alpha_val=[]
beta_val=[]
gamma_val=[]
mapeval=[]

for i in alpha:
    for j in beta:
        for k in gamma:
            model_fit=model.fit(smoothing_level=i, smoothing_slope=j, smoothing_seasonal=k, optimized=False)
            fcst = model_fit.forecast(len(test['Price per Kg']))
            alpha_val.append(i)
            beta_val.append(j)
            gamma_val.append(k)
            mapeval.append(mape(test['Price per Kg'], fcst))

# %%
a=pd.DataFrame({'alpha': alpha_val, 'beta': beta_val,'gamma': gamma_val, 'MAPE': mapeval})
a=a.sort_values('MAPE').reset_index()
a.drop('index',axis=1, inplace=True)
a.iloc[0]
# Out:
# alpha    0.05
# beta     0.10
# gamma    0.40
# MAPE     2.37
# Name: 0, dtype: float64

# %%
model_fit = model.fit(smoothing_level=0.05,smoothing_slope=0.10, smoothing_seasonal=0.40,optimized=False)
fcst = model_fit.forecast(len(test))
#fttval = model_fit.fittedvalues
test['ForecastHW'] = fcst

# %%
plt.figure(figsize=(15,8))
plt.plot(train.Timeindex, train['Price per Kg'], label = 'Train')
#plt.plot(train.Timeindex, fttval, label = 'Fitted Value')
plt.plot(test.Timeindex, test['Price per Kg'], label= 'Test')
plt.plot(test.Timeindex, test['ForecastHW'], label= 'Forecast')
plt.legend()
plt.show()

# %%
print('The MAPE value for Holt-Winters Model is : ', mape(test['Price per Kg'],test['ForecastHW']))
# Out:
# The MAPE value for Holt-Winters Model is :  2.37

# %% [markdown]
# ## 4. ARIMA Model

# %% [markdown]
# ### Stationarizing the series

# %%
plt.figure(figsize=(15,8))
plt.plot(train.Timeindex, train['Price per Kg'].diff(periods=1), label = 'Train')
plt.legend()
plt.show()

# %%
price_station = train['Price per Kg'].diff(periods=1)
price_station.dropna(inplace=True)
stattest = adfuller(price_station)
stattest
# Out:
# (-15.68250370612691,
#  1.4668452762995034e-28,
#  0,
#  202,
#  {'1%': -3.4631437906252636,
#   '5%': -2.8759570379821047,
#   '10%': -2.574454682874228},
#  963.0342364127596)

# %%
lag_acf=acf(price_station, nlags=20)
lag_pacf = pacf(price_station, nlags=20)

# %%
lag_acf
# Out:
# array([ 1.        , -0.10365404,  0.04694201,  0.01658323,  0.05562824,
#        -0.00372988,  0.09746692, -0.00583614, -0.04050004, -0.05121215,
#         0.03268216, -0.0280157 , -0.0399109 ,  0.0123351 , -0.08296702,
#        -0.03765145,  0.02861227,  0.03918212, -0.04898822,  0.00228229,
#        -0.01145034])

# %%
plt.figure(figsize=(18,8))
plt.plot(lag_acf)
plt.axhline(0, linestyle = '--', color='grey')
plt.axhline(1.96/np.sqrt(len(price_station)), linestyle = '--', color='grey')
plt.plot(lag_pacf)
plt.xticks(range(0,21))
plt.show()

# %% [markdown]
# We can infer from fuller test that the series is stationary

# %%
smt.graphics.plot_acf(price_station, lags=24)
smt.graphics.plot_pacf(price_station, lags=24)
plt.show()

# %% [markdown]
# From partial correlation, ignore the 0 lag and then check significatn spikes in timeseries, there are two spikes so we will take AR(2) for the model. Also the cutoff in Auto-corelation graph is at 0 lag, so the best model will habe MA(0). Difference we already know is 1. So with this information we can do ARIMA(2,1,0) model for the dataset.
#
# We will also check AIC to get best parameters

# %%
p=d=q=range(0,3)

# %%
pdq = list(itertools.product(p,d,q))

# %%
aic_val=[]
pdq_val=[]
for i in pdq:
    try:
        model = ARIMA(train['Price per Kg'], order= i)
        model_fit = model.fit()
        aic_val.append(model_fit.aic)
        pdq_val.append(i)
    except:
        continue

# %%
a= pd.DataFrame({'pdq': pdq_val, 'AIC': aic_val})
a.sort_values('AIC', inplace=True)
a.iloc[0]
# Out:
# pdq    (1, 1, 0)
# AIC      1061.68
# Name: 9, dtype: object

# %%
model = ARIMA(train['Price per Kg'], order= (1,1,0))
model_fit = model.fit()
fcst=model_fit.forecast(steps=24)[0]
test['ForecastAR'] = fcst

# %%
plt.figure(figsize=(15,8))
plt.plot(train.Timeindex, train['Price per Kg'], label = 'Train')
plt.plot(test.Timeindex, test['Price per Kg'], label= 'Test')
plt.plot(test.Timeindex, test['ForecastAR'], label= 'Forecast')
plt.legend()
plt.show()

# %%
print('The MAPE value for ARIMA Model is : ', mape(test['Price per Kg'],test['ForecastAR']))
# Out:
# The MAPE value for ARIMA Model is :  7.58

# %% [markdown]
# ## 5. Seasonal ARIMA

# %%
p=d=q=range(0,2)
pdq = list(itertools.product(p,d,q))
seasonal_pdq = [(x[0],x[1],x[2],12) for x in pdq]

# %%
aic_val = []
pdq_val = []
spdq_val = []

for i in pdq:
    for j in seasonal_pdq:
        try:
            model = sm.tsa.statespace.SARIMAX(train['Price per Kg'], order=i,seasonal_order=j,enforce_stationarity=True)
            model_fit = model.fit()
            aic_val.append(model_fit.aic)
            pdq_val.append(i)
            spdq_val.append(j)
        except:
            continue

# %%
a= pd.DataFrame({'pdq': pdq_val, 'spdq': spdq_val, 'AIC': aic_val})
a.sort_values('AIC', inplace=True)
a.iloc[0]
# Out:
# pdq         (0, 1, 0)
# spdq    (1, 1, 1, 12)
# AIC           1028.27
# Name: 17, dtype: object

# %%
model = sm.tsa.statespace.SARIMAX(train['Price per Kg'], order=(0,1,0),seasonal_order=(1,1,1,12),enforce_stationarity=True)
model_fit = model.fit()
fcst=model_fit.forecast(steps=24)
test['ForecastSAR'] = fcst

# %%
plt.figure(figsize=(15,8))
plt.plot(train.Timeindex, train['Price per Kg'], label = 'Train')
plt.plot(test.Timeindex, test['Price per Kg'], label= 'Test')
plt.plot(test.Timeindex, test['ForecastSAR'], label= 'Forecast')
plt.legend()
plt.show()

# %%
print('The MAPE value for Seasonal ARIMA Model is : ', mape(test['Price per Kg'],test['ForecastSAR']))
# Out:
# The MAPE value for Seasonal ARIMA Model is :  8.03

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Commodity', data=como)
plt.title('Commodities')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Region', data=como)
plt.title('Regions')
plt.show()

# %%
dal.head()
# Out:
#   Month-year  Price per Kg Month  Year  Timeindex
# 0    1997-01    104.666667   Jan  1997 1997-01-31
# 1    1997-02    104.666667   Feb  1997 1997-02-28
# 2    1997-03    104.666667   Mar  1997 1997-03-31
# 3    1997-04    104.666667   Apr  1997 1997-04-30
# 4    1997-05     96.000000   May  1997 1997-05-31

# %%
como.head()
# Out:
#          Date     Centre      Commodity  Price per Kg Region Country  \
# 0  25-11-1997    LUCKNOW  Tur/Arhar Dal          15.0  NORTH   INDIA
# 1  25-11-1997     BHOPAL  Tur/Arhar Dal          18.0   WEST   INDIA
# 2  25-11-1997     JAIPUR  Tur/Arhar Dal          20.0   WEST   INDIA
# 3  25-11-1997     SHIMLA  Tur/Arhar Dal          21.5  NORTH   INDIA
# 4  25-11-1997  AHMEDABAD  Tur/Arhar Dal          21.5   WEST   INDIA
#
#    Timeindex Month-year
# 0 1997-11-25    1997-11
# 1 1997-11-25    1997-11
# 2 1997-11-25    1997-11
# 3 1997-11-25    1997-11
# 4 1997-11-25    1997-11

# %%
plt.figure(figsize=(15,8))
plt.plot(train.Timeindex, train['Price per Kg'], label = 'Train')
plt.plot(test.Timeindex, test['Price per Kg'], label= 'Test')
plt.savefig('train-test')
plt.legend()
plt.show()

# %%
test
# Out:
#     Month-year  Price per Kg Month  Year  Timeindex  ForecastSE  ForecastDE  \
# 204    2014-01    221.231939   Jan  2014 2014-01-31  208.995381  217.594338
# 205    2014-02    218.494163   Feb  2014 2014-02-28  208.995381  216.822490
# 206    2014-03    219.439189   Mar  2014 2014-03-31  208.995381  216.050642
# 207    2014-04    220.357143   Apr  2014 2014-04-30  208.995381  215.278794
# 208    2014-05    215.085809   May  2014 2014-05-31  208.995381  214.506946
# 209    2014-06    216.574913   Jun  2014 2014-06-30  208.995381  213.735097
# 210    2014-07    211.986348   Jul  2014 2014-07-31  208.995381  212.963249
# 211    2014-08    211.780220   Aug  2014 2014-08-31  208.995381  212.191401
# 212    2014-09    209.888889   Sep  2014 2014-09-30  208.995381  211.419553
# 213    2014-10    209.618750   Oct  2014 2014-10-31  208.995381  210.647705
# 214    2014-11    211.574132   Nov  2014 2014-11-30  208.995381  209.875857
# 215    2014-12    207.964401   Dec  2014 2014-12-31  208.995381  209.104009
# 216    2015-01    205.054299   Jan  2015 2015-01-31  208.995381  208.332161
# 217    2015-02    209.246305   Feb  2015 2015-02-28  208.995381  207.560313
# 218    2015-03    205.866667   Mar  2015 2015-03-31  208.995381  206.788465
# 219    2015-04    204.008889   Apr  2015 2015-04-30  208.995381  206.016616
# 220    2015-05    199.972973   May  2015 2015-05-31  208.995381  205.244768
# 221    2015-06    204.620000   Jun  2015 2015-06-30  208.995381  204.472920
# 222    2015-07    202.093750   Jul  2015 2015-07-31  208.995381  203.701072
# 223    2015-08    203.500000   Aug  2015 2015-08-31  208.995381  202.929224
# 224    2015-09    204.484375   Sep  2015 2015-09-30  208.995381  202.157376
# 225    2015-10    204.811321   Oct  2015 2015-10-31  208.995381  201.385528
# 226    2015-11    206.181818   Nov  2015 2015-11-30  208.995381  200.613680
# 227    2015-12    205.285714   Dec  2015 2015-12-31  208.995381  199.841832
#
#      ForecastHW  ForecastAR  ForecastSAR
# 204  212.496742  218.481013   221.090225
# 205  208.782312  219.060223   219.785044
# 206  207.669274  219.616321   219.135391
# 207  207.986686  220.174807   218.729285
# 208  208.916739  220.733047   219.659123
# 209  208.316252  221.291312   220.276154
# 210  210.177136  221.849574   221.289136
# 211  208.274700  222.407837   221.503489
# 212  209.929693  222.966099   221.490229
# 213  208.136458  223.524362   222.775702
# 214  211.014396  224.082625   225.531202
# 215  208.018028  224.640887   226.183872
# 216  212.496742  225.199150   229.989646
# 217  208.782312  225.757413   228.274091
# 218  207.669274  226.315675   227.674668
# 219  207.986686  226.873938   227.694267
# 220  208.916739  227.432201   228.693355
# 221  208.316252  227.990464   229.287342
# 222  210.177136  228.548726   230.623248
# 223  208.274700  229.106989   230.289368
# 224  209.929693  229.665252   230.945834
# 225  208.136458  230.223514   231.468914
# 226  211.014396  230.781777   234.061595
# 227  208.018028  231.340040   234.969676

# %%
def rmse_val(par1, par2):
    val = np.sqrt(np.mean(np.square(par1-par2)))
    return val

ac = test['Price per Kg']
se = test['ForecastSE']
de = test['ForecastDE']
hw = test['ForecastHW']
ar = test['ForecastAR']
sr = test['ForecastSAR']

print('SE: ', rmse_val(ac,se))
print('DE: ', rmse_val(ac,de))
print('HW: ', rmse_val(ac,hw))
print('AR: ', rmse_val(ac,ar))
print('SR: ', rmse_val(ac,sr))
# Out:
# SE:  6.077377814291853
# DE:  2.8678349335158373
# HW:  6.172923635828114
# AR:  18.15475417892474
# SR:  19.482024589275994
